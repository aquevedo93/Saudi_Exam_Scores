# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import re
import pandas as pd
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException
import time

# %%
url= 'https://www.qiyas.sa/en/Statistics-Data/Schools/Pages/DetResults.aspx'

#Create a new Safari browser object
driver = webdriver.Safari()
driver.implicitly_wait(100)

#Go to the website
driver.get(url)

##Extract data for Capabilities, Girls, Scientific, Private##
    
#Click on 'Capabilities'
driver.find_element_by_xpath('/html/body/form/div[3]/div/div/section/div[2]/div/div[1]/article/div[2]/div[1]/div/div/div/div[1]/div/span/div[1]/div/table/tbody/tr[1]/td/div/div[1]/div').click()

#Click on 'Girls'
driver.find_element_by_xpath('/html/body/form/div[3]/div/div/section/div[2]/div/div[1]/article/div[2]/div[1]/div/div/div/div[1]/div/span/div[1]/div/table/tbody/tr[2]/td/div/div[2]/div/label').click() 

#Click on 'Scientific'
driver.find_element_by_xpath('/html/body/form/div[3]/div/div/section/div[2]/div/div[1]/article/div[2]/div[1]/div/div/div/div[1]/div/span/div[1]/div/table/tbody/tr[3]/td/div/div[1]').click() 

#Click on 'Private'
driver.find_element_by_xpath('/html/body/form/div[3]/div/div/section/div[2]/div/div[1]/article/div[2]/div[1]/div/div/div/div[1]/div/span/div[1]/div/table/tbody/tr[4]/td/div/div[2]/div').click() 

#Click on 'View the order of all schools'
driver.find_element_by_xpath('/html/body/form/div[3]/div/div/section/div[2]/div/div[1]/article/div[2]/div[1]/div/div/div/div[1]/div/span/div[1]/div/table/tbody/tr[5]/td/span[1]/label').click() 

#Click on 'Submit'
driver.find_element_by_xpath('/html/body/form/div[3]/div/div/section/div[2]/div/div[1]/article/div[2]/div[1]/div/div/div/div[1]/div/span/div[2]/div').click()

# %%
#Retrieving table from first page 
time.sleep(5)
soup_cbsp= BeautifulSoup(driver.page_source, 'html.parser')

#Parse and extract data 
table= soup_cbsp.find_all(class_='table-responsive')[1]

rows=table.find_all('tr')

COLUMNS= ['General Rank', 'Ministerial Number', 'School Name', 
          'City', 'Region', 'School Type', 'Category', 'Average']

sub_df=[]
for row in rows:
    cells= row.select('td')
    cells=cells[0:8]
    sub_df.append([cell.text.strip() for cell in cells])

data_cgsp = pd.DataFrame(sub_df, columns=COLUMNS).drop([0,1], axis=0).reset_index(drop=True)
data_cgsp
# Out:
#   General Rank Ministerial Number  \
# 0            2              55915
# 1            3              48917
# 2            4              55919
# 3            5              59009
# 4            7             422495
# 5            9              96623
# 6           10              35073
# 7           12              35066
# 8           14             559165
# 9           15              49001
#
#                                          School Name             City  \
# 0              ثانوية مدارس الظهران الاهلية (مقررات)            الخبر
# 1                       ثانوية الغد النموذجية ببريدة            بريدة
# 2                ثانوية مدارس الجامعة الاهلية للبنات            الخبر
# 3                             ثانوية الانجال الأهلية          الأحساء
# 4  مدارس منارات المدينة المنورة الأهلية - المرحلة...  المدينة المنورة
# 5                               ثانوية الفهد الأهلية           الرياض
# 6                                    ثانوية الصالحية              جدة
# 7                      ثانوية الذكر بجدة نظام مقررات              جدة
# 8    ثانوية مدارس الفيصلية الإسلامية بالخبر (مقررات)            الخبر
# 9                 ثانوية طلائع القصيم الأهلية ببريدة            بريدة
#
#        Region School Type        Category Average
# 0  AlSharquia    Domestic          مقررات      88
# 1      Qassim    Domestic  تعليم عام بنات   85.43
# 2  AlSharquia    Domestic  تعليم عام بنات   85.06
# 3  AlSharquia    Domestic  تعليم عام بنات      85
# 4      Madina    Domestic          مقررات   84.12
# 5      Riyadh    Domestic  تعليم عام بنات    83.2
# 6      Makkah    Domestic  تعليم عام بنات   82.79
# 7      Makkah    Domestic          مقررات   81.93
# 8  AlSharquia    Domestic          مقررات   81.58
# 9      Qassim    Domestic  تعليم عام بنات   81.57

# %%
while True:
    try:
        next_page_btn= driver.find_elements(By.CLASS_NAME, "Next")
        if not next_page_btn:
            print("No next button")
            break
        next_btn= next_page_btn[0]
        if next_btn.get_attribute("class")== "aspNetDisabled Next":
            print("No more pages left")
            break
        else:
            WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.CLASS_NAME, "Next"))).click()
        
            time.sleep(10)
       
            soup_pgs= BeautifulSoup(driver.page_source, 'html.parser')
        
            #Parse and extract data 
            table_pgs= soup_pgs.find_all(class_='table-responsive')[1]
        
            rows_pgs=table_pgs.find_all('tr')
        
            COLUMNS_pgs= ['General Rank', 'Ministerial Number', 'School Name', 
              'City', 'Region', 'School Type', 'Category', 'Average']
        
            sub_df_pgs=[]
            for row_pgs in rows_pgs:
                cells_pgs= row_pgs.select('td')
                cells_pgs=cells_pgs[0:8]
                sub_df_pgs.append([cell_pgs.text.strip() for cell_pgs in cells_pgs])
        
            data_pgs = pd.DataFrame(sub_df_pgs, columns=COLUMNS_pgs).drop([0,1], axis=0).reset_index(drop=True)
            data_cgsp=data_cgsp.append(data_pgs, ignore_index=True)
    except TimeoutException:
        time.sleep(10)
        print("Exception has been thrown. No more pages left")
        break
driver.quit()
# Out:
# No more pages left

# %%
data_cgsp.drop(data_cgsp.tail(1).index,inplace=True)

# %%
data_cgsp
# Out:
#     General Rank Ministerial Number  \
# 0              2              55915
# 1              3              48917
# 2              4              55919
# 3              5              59009
# 4              7             422495
# 5              9              96623
# 6             10              35073
# 7             12              35066
# 8             14             559165
# 9             15              49001
# 10            16              96749
# 11            17             155010
# 12            18              55921
# 13            19             966465
# 14            21              96953
# 15            23              96676
# 16            24             966645
# 17            25              56201
# 18            27              56292
# 19            28             195029
# 20            29              96642
# 21            31             966305
# 22            32              59008
# 23            36              55694
# 24            38              55917
# 25            40              96670
# 26            43              35217
# 27            44              96633
# 28            50              96640
# 29            51              35042
# ..           ...                ...
# 300         1597              77930
# 301         1616              60844
# 302         1623             128857
# 303         1627              97070
# 304         1646              89463
# 305         1650              28389
# 306         1667              83801
# 307         1683             118004
# 308         1697             185634
# 309         1724              86699
# 310         1730              60817
# 311         1736              28321
# 312         1738             197237
# 313         1766              23733
# 314         1793              78165
# 315         1804              97235
# 316         1823              60831
# 317         1830              51311
# 318         1836              89486
# 319         1866             189145
# 320         1881             189143
# 321         1922              85253
# 322         1925             188528
# 323         1931             192047
# 324         1958              60738
# 325         1961              60814
# 326         1965              85337
# 327         2013             197035
# 328         2020              23761
# 329         2051              60886
#
#                                            School Name             City  \
# 0                ثانوية مدارس الظهران الاهلية (مقررات)            الخبر
# 1                         ثانوية الغد النموذجية ببريدة            بريدة
# 2                  ثانوية مدارس الجامعة الاهلية للبنات            الخبر
# 3                               ثانوية الانجال الأهلية          الأحساء
# 4    مدارس منارات المدينة المنورة الأهلية - المرحلة...  المدينة المنورة
# 5                                 ثانوية الفهد الأهلية           الرياض
# 6                                      ثانوية الصالحية              جدة
# 7                        ثانوية الذكر بجدة نظام مقررات              جدة
# 8      ثانوية مدارس الفيصلية الإسلامية بالخبر (مقررات)            الخبر
# 9                   ثانوية طلائع القصيم الأهلية ببريدة            بريدة
# 10                         ثانوية شموخ الأجيال الأهلية           الرياض
# 11          مدارس السلام الخاصة للبنات - نظام المقررات            الخبر
# 12                ثانوية مدارس العزيزيه الاهلية للبنات            الخبر
# 13         ثانوية الرواد الأهلية ( الازدهار ) - مقررات           الرياض
# 14                     ثانوية الفيصلية الحديثة الأهلية           الرياض
# 15                                 ثانوية الغد الأهلية           الرياض
# 16                     ثانوية التربية الأهلية - مقررات           الرياض
# 17          ثانوية مدارس البسام الاهلية للبنات -مقررات           الدمام
# 18   ثانوية مدارس الحصان النموذجية الأهلية ورياض ال...           الدمام
# 19                   ثانوية الفرسان الأهلية - المقررات           الرياض
# 20                              ثانوية العربية الأهلية           الرياض
# 21               ثانوية منارات الرياض الأهلية - مقررات           الرياض
# 22                           ثانوية دور العلوم الأهلية          الأحساء
# 23                 ثانوية مدارس التربية الأهلية بالخبر            الخبر
# 24               ثانوية مدارس  المنارات بالخبر الأهليه            الخبر
# 25                              ثانوية الحرمين الأهلية           الرياض
# 26                             ثانوية أكاديمية المعارف              جدة
# 27                                  ثانوية نجد الأهلية           الرياض
# 28                              ثانوية العناية الأهلية           الرياض
# 29                     ثانوية الزهراء بجدة نظام مقررات              جدة
# ..                                                 ...              ...
# 300                  ثانوية دار الحنان النموذجية بتبوك             تبوك
# 301                         ثانوية نور التوحيد الأهلية       حفر الباطن
# 302                 ثانوية الطموح الأهلية بمكة المكرمة      مكة المكرمة
# 303                        ثانوية أضواء الرياض الأهلية           الرياض
# 304                 ثانوية  مدارس جازان الأهلية للبنات            جازان
# 305          ثانوية مواهب المملكة الأهلية بمكة المكرمة      مكة المكرمة
# 306                    ثانوية أنجال رفحاء الأهلية-بنات            رفحاء
# 307                          ثانوية نهج التميز الأهلية             ساجر
# 308                         ثانوية وارفة العلم الأهلية            سكاكا
# 309                             ثانوية القريات الاهلية          القريات
# 310                  ثانوية الأكاديمية العصرية الأهلية       حفر الباطن
# 311                  ثانوية الفضل الأهلية بمكة المكرمة      مكة المكرمة
# 312                         ثانوية مداد البيان الأهلية           الرياض
# 313                        ثانوية  منارات عفيف الاهلية             عفيف
# 314                         ثانوية قطوف الايمان بتيماء            تيماء
# 315                    ثانوية منارات المزاحمية الأهلية        المزاحمية
# 316                         ثانوية رواد النجاح الأهلية       حفر الباطن
# 317                          ثانوية درة الملبي الأهلية             الرس
# 318                         ثانوية جوهره الفكر الأهلية            جازان
# 319        ثانوية اجياد التميز الاهلية - نظام المقررات         أبو عريش
# 320                        ثانوية اجياد التميز الاهلية         أبو عريش
# 321                               ثانوية القمم الأهلية            سكاكا
# 322                      ثانوية زهرات المستقبل الأهلية            جازان
# 323                         مدارس أرقى المناهل الأهليه             صبيا
# 324                              ثانوية الواحة الأهلية       حفر الباطن
# 325                               ثانوية المجد الأهلية       حفر الباطن
# 326          ثانوية فتيات الأوائل الأهلية بدومة الجندل      دومة الجندل
# 327           ثانوية دار النهل الأهلية لتعليم الكبيرات           الرياض
# 328                    ثانوية الصفوة النموذجية الأهلية             عفيف
# 329          ثانوية الأكاديمية العصرية لتعليم الكبيرات       حفر الباطن
#
#                Region School Type        Category Average
# 0          AlSharquia    Domestic          مقررات      88
# 1              Qassim    Domestic  تعليم عام بنات   85.43
# 2          AlSharquia    Domestic  تعليم عام بنات   85.06
# 3          AlSharquia    Domestic  تعليم عام بنات      85
# 4              Madina    Domestic          مقررات   84.12
# 5              Riyadh    Domestic  تعليم عام بنات    83.2
# 6              Makkah    Domestic  تعليم عام بنات   82.79
# 7              Makkah    Domestic          مقررات   81.93
# 8          AlSharquia    Domestic          مقررات   81.58
# 9              Qassim    Domestic  تعليم عام بنات   81.57
# 10             Riyadh    Domestic  تعليم عام بنات   81.55
# 11         AlSharquia    Domestic          مقررات   81.52
# 12         AlSharquia    Domestic  تعليم عام بنات    81.4
# 13             Riyadh    Domestic          مقررات   81.36
# 14             Riyadh    Domestic  تعليم عام بنات   81.26
# 15             Riyadh    Domestic  تعليم عام بنات   80.97
# 16             Riyadh    Domestic          مقررات   80.84
# 17         AlSharquia    Domestic          مقررات   80.76
# 18         AlSharquia    Domestic          مقررات   80.51
# 19             Riyadh    Domestic          مقررات   80.45
# 20             Riyadh    Domestic  تعليم عام بنات   80.33
# 21             Riyadh    Domestic          مقررات   80.28
# 22         AlSharquia    Domestic  تعليم عام بنات   80.22
# 23         AlSharquia    Domestic  تعليم عام بنات   79.89
# 24         AlSharquia    Domestic  تعليم عام بنات   79.77
# 25             Riyadh    Domestic  تعليم عام بنات   79.62
# 26             Makkah    Domestic  تعليم عام بنات   79.57
# 27             Riyadh    Domestic  تعليم عام بنات   79.45
# 28             Riyadh    Domestic  تعليم عام بنات   79.11
# 29             Makkah    Domestic          مقررات   78.96
# ..                ...         ...             ...     ...
# 300             Tabuk    Domestic  تعليم عام بنات   64.42
# 301        AlSharquia    Domestic  تعليم عام بنات   64.23
# 302            Makkah    Domestic  تعليم عام بنات   64.16
# 303            Riyadh    Domestic  تعليم عام بنات   64.13
# 304             Jazan    Domestic  تعليم عام بنات   63.94
# 305            Makkah    Domestic  تعليم عام بنات   63.91
# 306  Northern borders    Domestic  تعليم عام بنات   63.74
# 307            Riyadh    Domestic  تعليم عام بنات   63.58
# 308              Gouf    Domestic  تعليم عام بنات   63.42
# 309              Gouf    Domestic  تعليم عام بنات   63.17
# 310        AlSharquia    Domestic  تعليم عام بنات   63.12
# 311            Makkah    Domestic  تعليم عام بنات   63.06
# 312            Riyadh    Domestic  تعليم عام بنات   63.03
# 313            Riyadh    Domestic  تعليم عام بنات   62.73
# 314             Tabuk    Domestic  تعليم عام بنات   62.44
# 315            Riyadh    Domestic  تعليم عام بنات   62.32
# 316        AlSharquia    Domestic  تعليم عام بنات   62.18
# 317            Qassim    Domestic  تعليم عام بنات   62.12
# 318             Jazan    Domestic  تعليم عام بنات   61.99
# 319             Jazan    Domestic          مقررات   61.54
# 320             Jazan    Domestic  تعليم عام بنات   61.38
# 321              Gouf    Domestic  تعليم عام بنات   60.92
# 322             Jazan    Domestic  تعليم عام بنات   60.82
# 323             Jazan    Domestic  تعليم عام بنات   60.76
# 324        AlSharquia    Domestic  تعليم عام بنات   60.29
# 325        AlSharquia    Domestic  تعليم عام بنات   60.19
# 326              Gouf    Domestic  تعليم عام بنات   60.03
# 327            Riyadh    Domestic  تعليم عام بنات   58.95
# 328            Riyadh    Domestic  تعليم عام بنات   58.83
# 329        AlSharquia    Domestic  تعليم عام بنات   57.74
#
# [330 rows x 8 columns]

# %%
data_cgsp.to_csv('data/cap_girls_sci_priv.csv', index=False)
