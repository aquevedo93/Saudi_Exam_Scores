# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import re
import pandas as pd
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException
import time

# %%
url= 'https://www.qiyas.sa/en/Statistics-Data/Schools/Pages/DetResults.aspx'

#Create a new Safari browser object
driver = webdriver.Safari()
driver.implicitly_wait(100)

#Go to the website
driver.get(url)

##Extract data for Achievement, Girls, Scientific, Private##
    
#Click on 'Achievement'
driver.find_element_by_xpath('/html/body/form/div[3]/div/div/section/div[2]/div/div[1]/article/div[2]/div[1]/div/div/div/div[1]/div/span/div[1]/div/table/tbody/tr[1]/td/div/div[2]/div/label').click()

#Click on 'Girls'
driver.find_element_by_xpath('/html/body/form/div[3]/div/div/section/div[2]/div/div[1]/article/div[2]/div[1]/div/div/div/div[1]/div/span/div[1]/div/table/tbody/tr[2]/td/div/div[2]/div/label').click() 

#Click on 'Scientific'
driver.find_element_by_xpath('/html/body/form/div[3]/div/div/section/div[2]/div/div[1]/article/div[2]/div[1]/div/div/div/div[1]/div/span/div[1]/div/table/tbody/tr[3]/td/div/div[1]').click() 

#Click on 'Private'
driver.find_element_by_xpath('/html/body/form/div[3]/div/div/section/div[2]/div/div[1]/article/div[2]/div[1]/div/div/div/div[1]/div/span/div[1]/div/table/tbody/tr[4]/td/div/div[2]/div').click() 

#Click on 'View the order of all schools'
driver.find_element_by_xpath('/html/body/form/div[3]/div/div/section/div[2]/div/div[1]/article/div[2]/div[1]/div/div/div/div[1]/div/span/div[1]/div/table/tbody/tr[5]/td/span[1]/label').click() 

#Click on 'Submit'
driver.find_element_by_xpath('/html/body/form/div[3]/div/div/section/div[2]/div/div[1]/article/div[2]/div[1]/div/div/div/div[1]/div/span/div[2]/div').click()

# %%
#Retrieving table from first page 
time.sleep(5)
soup_cbsp= BeautifulSoup(driver.page_source, 'html.parser')

#Parse and extract data 
table= soup_cbsp.find_all(class_='table-responsive')[1]

rows=table.find_all('tr')

COLUMNS= ['General Rank', 'Ministerial Number', 'School Name', 
          'City', 'Region', 'School Type', 'Category', 'Average']

sub_df=[]
for row in rows:
    cells= row.select('td')
    cells=cells[0:8]
    sub_df.append([cell.text.strip() for cell in cells])

data_agsp = pd.DataFrame(sub_df, columns=COLUMNS).drop([0,1], axis=0).reset_index(drop=True)
data_agsp
# Out:
#   General Rank Ministerial Number  \
# 0            1              55915
# 1            2              55919
# 2            3             422495
# 3            4             155010
# 4            5              55921
# 5            6              96623
# 6            7              35066
# 7            8              59009
# 8           12              35042
# 9           13              56201
#
#                                          School Name             City  \
# 0              ثانوية مدارس الظهران الاهلية (مقررات)            الخبر
# 1                ثانوية مدارس الجامعة الاهلية للبنات            الخبر
# 2  مدارس منارات المدينة المنورة الأهلية - المرحلة...  المدينة المنورة
# 3         مدارس السلام الخاصة للبنات - نظام المقررات            الخبر
# 4               ثانوية مدارس العزيزيه الاهلية للبنات            الخبر
# 5                               ثانوية الفهد الأهلية           الرياض
# 6                      ثانوية الذكر بجدة نظام مقررات              جدة
# 7                             ثانوية الانجال الأهلية          الأحساء
# 8                    ثانوية الزهراء بجدة نظام مقررات              جدة
# 9         ثانوية مدارس البسام الاهلية للبنات -مقررات           الدمام
#
#        Region School Type        Category Average
# 0  AlSharquia    Domestic          مقررات      92
# 1  AlSharquia    Domestic  تعليم عام بنات   87.51
# 2      Madina    Domestic          مقررات   87.46
# 3  AlSharquia    Domestic          مقررات   87.24
# 4  AlSharquia    Domestic  تعليم عام بنات   86.72
# 5      Riyadh    Domestic  تعليم عام بنات   86.26
# 6      Makkah    Domestic          مقررات   86.19
# 7  AlSharquia    Domestic  تعليم عام بنات   86.13
# 8      Makkah    Domestic          مقررات   85.23
# 9  AlSharquia    Domestic          مقررات   85.07

# %%
while True:
    try:
        next_page_btn= driver.find_elements(By.CLASS_NAME, "Next")
        if not next_page_btn:
            print("No next button")
            break
        next_btn= next_page_btn[0]
        if next_btn.get_attribute("class")== "aspNetDisabled Next":
            print("No more pages left")
            break
        else:
            WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.CLASS_NAME, "Next"))).click()
        
            time.sleep(10)
       
            soup_pgs= BeautifulSoup(driver.page_source, 'html.parser')
        
            #Parse and extract data 
            table_pgs= soup_pgs.find_all(class_='table-responsive')[1]
        
            rows_pgs=table_pgs.find_all('tr')
        
            COLUMNS_pgs= ['General Rank', 'Ministerial Number', 'School Name', 
              'City', 'Region', 'School Type', 'Category', 'Average']
        
            sub_df_pgs=[]
            for row_pgs in rows_pgs:
                cells_pgs= row_pgs.select('td')
                cells_pgs=cells_pgs[0:8]
                sub_df_pgs.append([cell_pgs.text.strip() for cell_pgs in cells_pgs])
        
            data_pgs = pd.DataFrame(sub_df_pgs, columns=COLUMNS_pgs).drop([0,1], axis=0).reset_index(drop=True)
            data_agsp=data_agsp.append(data_pgs, ignore_index=True)
    except TimeoutException:
        time.sleep(10)
        print("Exception has been thrown. No more pages left")
        break
driver.quit()
# Out:
# No more pages left

# %%
data_agsp
# Out:
#     General Rank Ministerial Number  \
# 0              1              55915
# 1              2              55919
# 2              3             422495
# 3              4             155010
# 4              5              55921
# 5              6              96623
# 6              7              35066
# 7              8              59009
# 8             12              35042
# 9             13              56201
# 10            15             559165
# 11            17              55694
# 12            19             966465
# 13            20              55693
# 14            24              96676
# 15            28             195029
# 16            30              96953
# 17            32              56292
# 18            35             966645
# 19            48              35047
# 20            50              96633
# 21            52              28326
# 22            61             351805
# 23            80              96626
# 24            81              35053
# 25            82              35078
# 26            91              59099
# 27           100              56262
# 28           101              35179
# 29           105              35045
# ..           ...                ...
# 285         1716              75068
# 286         1735              48982
# 287         1739              60844
# 288         1740              85215
# 289         1766              89486
# 290         1777              22369
# 291         1778              86699
# 292         1779              97235
# 293         1780             185634
# 294         1789             188528
# 295         1790              51311
# 296         1798              85392
# 297         1799              95964
# 298         1801              89463
# 299         1802              89503
# 300         1806              60817
# 301         1807              18567
# 302         1817              23761
# 303         1818              60831
# 304         1822              60738
# 305         1824             185009
# 306         1830              48918
# 307         1833              85337
# 308         1834              83801
# 309         1836              83874
# 310         1839              60814
# 311         1847              85253
# 312         1849             189139
# 313         1852              23733
# 314         1854              60886
#
#                                            School Name             City  \
# 0                ثانوية مدارس الظهران الاهلية (مقررات)            الخبر
# 1                  ثانوية مدارس الجامعة الاهلية للبنات            الخبر
# 2    مدارس منارات المدينة المنورة الأهلية - المرحلة...  المدينة المنورة
# 3           مدارس السلام الخاصة للبنات - نظام المقررات            الخبر
# 4                 ثانوية مدارس العزيزيه الاهلية للبنات            الخبر
# 5                                 ثانوية الفهد الأهلية           الرياض
# 6                        ثانوية الذكر بجدة نظام مقررات              جدة
# 7                               ثانوية الانجال الأهلية          الأحساء
# 8                      ثانوية الزهراء بجدة نظام مقررات              جدة
# 9           ثانوية مدارس البسام الاهلية للبنات -مقررات           الدمام
# 10     ثانوية مدارس الفيصلية الإسلامية بالخبر (مقررات)            الخبر
# 11                 ثانوية مدارس التربية الأهلية بالخبر            الخبر
# 12         ثانوية الرواد الأهلية ( الازدهار ) - مقررات           الرياض
# 13                     ثانوية مدارس دار البيان الأهلية            الخبر
# 14                                 ثانوية الغد الأهلية           الرياض
# 15                   ثانوية الفرسان الأهلية - المقررات           الرياض
# 16                     ثانوية الفيصلية الحديثة الأهلية           الرياض
# 17   ثانوية مدارس الحصان النموذجية الأهلية ورياض ال...           الدمام
# 18                     ثانوية التربية الأهلية - مقررات           الرياض
# 19                           ثانوية النصيفية النموذجية              جدة
# 20                                  ثانوية نجد الأهلية           الرياض
# 21           ثانوية دوحة العلم الأهلية (نظام المقررات)      مكة المكرمة
# 22                     ثانوية الاندلس بجدة نظام مقررات              جدة
# 23           ثانوية التربية الإسلامية الأهلية - مقررات           الرياض
# 24                                   ثانوية منارات جدة              جدة
# 25                                       ثانوية العقيق              جدة
# 26                             ثانوية النخبة النموذجية          الأحساء
# 27   ثانوية  مدارس رياض الإحسان الاهلية للبنات بالدمام           الدمام
# 28                   ثانوية دارالقلم النموذجية الأهلية              جدة
# 29                 ثانوية البيان النموذجية نظام مقررات              جدة
# ..                                                 ...              ...
# 285                    ثانوية التربية  الإسلامية بحائل             حائل
# 286                ثانوية مناهل الإيمان الاهلية ببريدة            بريدة
# 287                         ثانوية نور التوحيد الأهلية       حفر الباطن
# 288                           ثانوية الرحمانية الأهلية            سكاكا
# 289                         ثانوية جوهره الفكر الأهلية            جازان
# 290                  ثانوية اجيال المعرفة الاهلية بنات         القويعية
# 291                             ثانوية القريات الاهلية          القريات
# 292                    ثانوية منارات المزاحمية الأهلية        المزاحمية
# 293                         ثانوية وارفة العلم الأهلية            سكاكا
# 294                      ثانوية زهرات المستقبل الأهلية            جازان
# 295                          ثانوية درة الملبي الأهلية             الرس
# 296                             ثانوية التجديد الاهليه            سكاكا
# 297                             ثانوية الأركان الأهلية           الرياض
# 298                 ثانوية  مدارس جازان الأهلية للبنات            جازان
# 299                       ثانوية مناهل الجامعة الأهلية            جازان
# 300                  ثانوية الأكاديمية العصرية الأهلية       حفر الباطن
# 301                      ثانوية أجيال الدوادمي الأهلية         الدوادمي
# 302                    ثانوية الصفوة النموذجية الأهلية             عفيف
# 303                         ثانوية رواد النجاح الأهلية       حفر الباطن
# 304                              ثانوية الواحة الأهلية       حفر الباطن
# 305                       ثانوية منهاج الرسالة الأهلية            سكاكا
# 306                 ثانوية أنجال القصيم الأهلية ببريدة            بريدة
# 307          ثانوية فتيات الأوائل الأهلية بدومة الجندل      دومة الجندل
# 308                    ثانوية أنجال رفحاء الأهلية-بنات            رفحاء
# 309                           ثانوية شموس رفحاء برفحاء            رفحاء
# 310                               ثانوية المجد الأهلية       حفر الباطن
# 311                               ثانوية القمم الأهلية            سكاكا
# 312                      ثانوية تعليم الكبيرات الأهلية            جازان
# 313                        ثانوية  منارات عفيف الاهلية             عفيف
# 314          ثانوية الأكاديمية العصرية لتعليم الكبيرات       حفر الباطن
#
#                Region School Type        Category Average
# 0          AlSharquia    Domestic          مقررات      92
# 1          AlSharquia    Domestic  تعليم عام بنات   87.51
# 2              Madina    Domestic          مقررات   87.46
# 3          AlSharquia    Domestic          مقررات   87.24
# 4          AlSharquia    Domestic  تعليم عام بنات   86.72
# 5              Riyadh    Domestic  تعليم عام بنات   86.26
# 6              Makkah    Domestic          مقررات   86.19
# 7          AlSharquia    Domestic  تعليم عام بنات   86.13
# 8              Makkah    Domestic          مقررات   85.23
# 9          AlSharquia    Domestic          مقررات   85.07
# 10         AlSharquia    Domestic          مقررات   84.98
# 11         AlSharquia    Domestic  تعليم عام بنات   84.69
# 12             Riyadh    Domestic          مقررات   84.34
# 13         AlSharquia    Domestic  تعليم عام بنات   84.13
# 14             Riyadh    Domestic  تعليم عام بنات   83.77
# 15             Riyadh    Domestic          مقررات   83.54
# 16             Riyadh    Domestic  تعليم عام بنات   83.35
# 17         AlSharquia    Domestic          مقررات   83.09
# 18             Riyadh    Domestic          مقررات   82.92
# 19             Makkah    Domestic  تعليم عام بنات   82.34
# 20             Riyadh    Domestic  تعليم عام بنات   82.25
# 21             Makkah    Domestic          مقررات    82.2
# 22             Makkah    Domestic          مقررات   81.77
# 23             Riyadh    Domestic          مقررات   80.72
# 24             Makkah    Domestic  تعليم عام بنات   80.71
# 25             Makkah    Domestic  تعليم عام بنات   80.66
# 26         AlSharquia    Domestic  تعليم عام بنات   80.41
# 27         AlSharquia    Domestic  تعليم عام بنات   80.15
# 28             Makkah    Domestic  تعليم عام بنات   80.14
# 29             Makkah    Domestic          مقررات   80.09
# ..                ...         ...             ...     ...
# 285              Hail    Domestic  تعليم عام بنات   59.78
# 286            Qassim    Domestic  تعليم عام بنات   59.19
# 287        AlSharquia    Domestic  تعليم عام بنات   59.13
# 288              Gouf    Domestic  تعليم عام بنات   59.11
# 289             Jazan    Domestic  تعليم عام بنات    58.5
# 290            Riyadh    Domestic  تعليم عام بنات   58.16
# 291              Gouf    Domestic  تعليم عام بنات    58.1
# 292            Riyadh    Domestic  تعليم عام بنات   58.08
# 293              Gouf    Domestic  تعليم عام بنات   58.02
# 294             Jazan    Domestic  تعليم عام بنات    57.8
# 295            Qassim    Domestic  تعليم عام بنات   57.79
# 296              Gouf    Domestic  تعليم عام بنات   57.44
# 297            Riyadh    Domestic  تعليم عام بنات   57.43
# 298             Jazan    Domestic  تعليم عام بنات    57.3
# 299             Jazan    Domestic  تعليم عام بنات    57.3
# 300        AlSharquia    Domestic  تعليم عام بنات   57.02
# 301            Riyadh    Domestic  تعليم عام بنات   56.91
# 302            Riyadh    Domestic  تعليم عام بنات   56.38
# 303        AlSharquia    Domestic  تعليم عام بنات   56.14
# 304        AlSharquia    Domestic  تعليم عام بنات   55.87
# 305              Gouf    Domestic  تعليم عام بنات   55.81
# 306            Qassim    Domestic  تعليم عام بنات   55.44
# 307              Gouf    Domestic  تعليم عام بنات   55.36
# 308  Northern borders    Domestic  تعليم عام بنات   55.32
# 309  Northern borders    Domestic  تعليم عام بنات   55.11
# 310        AlSharquia    Domestic  تعليم عام بنات   54.94
# 311              Gouf    Domestic  تعليم عام بنات      54
# 312             Jazan    Domestic  تعليم عام بنات   53.58
# 313            Riyadh    Domestic  تعليم عام بنات   52.85
# 314        AlSharquia    Domestic  تعليم عام بنات    52.2
#
# [315 rows x 8 columns]

# %%
data_agsp.to_csv('ach_girls_sci_priv.csv', index=False)
