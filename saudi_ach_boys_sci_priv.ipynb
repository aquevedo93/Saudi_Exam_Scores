# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import re
import pandas as pd
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException
import time

# %%
url= 'https://www.qiyas.sa/en/Statistics-Data/Schools/Pages/DetResults.aspx'

#Create a new Safari browser object
driver = webdriver.Safari()
driver.implicitly_wait(100)

#Go to the website
driver.get(url)

##Extract data for Achievement, Boys, Scientific, Private##
    
#Click on 'Achievement'
driver.find_element_by_xpath('/html/body/form/div[3]/div/div/section/div[2]/div/div[1]/article/div[2]/div[1]/div/div/div/div[1]/div/span/div[1]/div/table/tbody/tr[1]/td/div/div[2]/div/label').click()

#Click on 'Boys'
driver.find_element_by_xpath('/html/body/form/div[3]/div/div/section/div[2]/div/div[1]/article/div[2]/div[1]/div/div/div/div[1]/div/span/div[1]/div/table/tbody/tr[2]/td/div/div[1]').click() 

#Click on 'Scientific'
driver.find_element_by_xpath('/html/body/form/div[3]/div/div/section/div[2]/div/div[1]/article/div[2]/div[1]/div/div/div/div[1]/div/span/div[1]/div/table/tbody/tr[3]/td/div/div[1]').click() 

#Click on 'Private'
driver.find_element_by_xpath('/html/body/form/div[3]/div/div/section/div[2]/div/div[1]/article/div[2]/div[1]/div/div/div/div[1]/div/span/div[1]/div/table/tbody/tr[4]/td/div/div[2]/div').click() 

#Click on 'View the order of all schools'
driver.find_element_by_xpath('/html/body/form/div[3]/div/div/section/div[2]/div/div[1]/article/div[2]/div[1]/div/div/div/div[1]/div/span/div[1]/div/table/tbody/tr[5]/td/span[1]/label').click() 

#Click on 'Submit'
driver.find_element_by_xpath('/html/body/form/div[3]/div/div/section/div[2]/div/div[1]/article/div[2]/div[1]/div/div/div/div[1]/div/span/div[2]/div').click()

# %%
#Retrieving table from first page 
time.sleep(5)
soup_cbsp= BeautifulSoup(driver.page_source, 'html.parser')

#Parse and extract data 
table= soup_cbsp.find_all(class_='table-responsive')[1]

rows=table.find_all('tr')

COLUMNS= ['General Rank', 'Ministerial Number', 'School Name', 
          'City', 'Region', 'School Type', 'Category', 'Average']

sub_df=[]
for row in rows:
    cells= row.select('td')
    cells=cells[0:8]
    sub_df.append([cell.text.strip() for cell in cells])

data_absp = pd.DataFrame(sub_df, columns=COLUMNS).drop([0,1], axis=0).reset_index(drop=True)
data_absp
# Out:
#   General Rank Ministerial Number  \
# 0            1              54421
# 1            2              53854
# 2            3              26504
# 3            5             153006
# 4            7              11179
# 5            8              11175
# 6            9              53936
# 7           11             538485
# 8           12              53853
# 9           13              11380
#
#                                         School Name         City      Region  \
# 0                      ثانوية اجيال المواهب الاهلية        الخبر  AlSharquia
# 1                            ثانوية الجامعة الأهلية        الخبر  AlSharquia
# 2                             ثانوية الفلاح الأهلية  مكة المكرمة      Makkah
# 3                            ثانوية المشكاة الأهلية       الدمام  AlSharquia
# 4                                ثانوية نجد الأهلية       الرياض      Riyadh
# 5                      ثانوية منارات الرياض الأهلية       الرياض      Riyadh
# 6                            ثانوية الانصار الأهلية       الدمام  AlSharquia
# 7  ثانوية الحصان النموذجية الاهلية بالدمام - مقررات       الدمام  AlSharquia
# 8                   ثانوية الظهران الاهلية - مقررات        الخبر  AlSharquia
# 9                               ثانوية الغد الأهلية       الرياض      Riyadh
#
#   School Type        Category Average
# 0    Domestic  تعليم عام بنين   88.41
# 1    Domestic  تعليم عام بنين   87.75
# 2    Domestic  تعليم عام بنين   86.93
# 3    Domestic  تعليم عام بنين   86.05
# 4    Domestic  تعليم عام بنين   85.57
# 5    Domestic          مقررات    85.4
# 6    Domestic  تعليم عام بنين   84.93
# 7    Domestic          مقررات   83.88
# 8    Domestic          مقررات   83.56
# 9    Domestic  تعليم عام بنين   82.91

# %%
while True:
    try:
        next_page_btn= driver.find_elements(By.CLASS_NAME, "Next")
        if not next_page_btn:
            print("No next button")
            break
        next_btn= next_page_btn[0]
        if next_btn.get_attribute("class")== "aspNetDisabled Next":
            print("No more pages left")
            break
        else:
            WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.CLASS_NAME, "Next"))).click()
        
            time.sleep(10)
       
            soup_pgs= BeautifulSoup(driver.page_source, 'html.parser')
        
            #Parse and extract data 
            table_pgs= soup_pgs.find_all(class_='table-responsive')[1]
        
            rows_pgs=table_pgs.find_all('tr')
        
            COLUMNS_pgs= ['General Rank', 'Ministerial Number', 'School Name', 
              'City', 'Region', 'School Type', 'Category', 'Average']
        
            sub_df_pgs=[]
            for row_pgs in rows_pgs:
                cells_pgs= row_pgs.select('td')
                cells_pgs=cells_pgs[0:8]
                sub_df_pgs.append([cell_pgs.text.strip() for cell_pgs in cells_pgs])
        
            data_pgs = pd.DataFrame(sub_df_pgs, columns=COLUMNS_pgs).drop([0,1], axis=0).reset_index(drop=True)
            data_absp=data_absp.append(data_pgs, ignore_index=True)
    except TimeoutException:
        time.sleep(10)
        print("Exception has been thrown. No more pages left")
        break
driver.quit()
# Out:
# No more pages left

# %%
data_absp
# Out:
#     General Rank Ministerial Number  \
# 0              1              54421
# 1              2              53854
# 2              3              26504
# 3              5             153006
# 4              7              11179
# 5              8              11175
# 6              9              53936
# 7             11             538485
# 8             12              53853
# 9             13              11380
# 10            14             111903
# 11            15              11176
# 12            19             405625
# 13            20              11183
# 14            21             405645
# 15            23              54225
# 16            24              76452
# 17            26             532845
# 18            28             538395
# 19            30              32822
# 20            33              11292
# 21            35              11185
# 22            38              33127
# 23            39              29739
# 24            41              11392
# 25            42              11776
# 26            47             110043
# 27            48              53852
# 28            49             153557
# 29            50              11178
# ..           ...                ...
# 371         1813              30143
# 372         1816             184002
# 373         1817              60427
# 374         1819              20285
# 375         1820              60453
# 376         1822             160009
# 377         1829              47546
# 378         1831             193009
# 379         1834              12094
# 380         1836              17495
# 381         1839              60432
# 382         1840             188470
# 383         1843              17519
# 384         1845              52246
# 385         1853              60387
# 386         1856              11314
# 387         1858              47842
# 388         1860             160010
# 389         1867              50372
# 390         1879             184013
# 391         1881             187644
# 392         1883              19156
# 393         1903              23316
# 394         1923              23335
# 395         1927              23332
# 396         1933              14228
# 397         1956              84349
# 398         1959             184011
# 399         1962              14227
# 400         1964             184308
#
#                                            School Name             City  \
# 0                         ثانوية اجيال المواهب الاهلية            الخبر
# 1                               ثانوية الجامعة الأهلية            الخبر
# 2                                ثانوية الفلاح الأهلية      مكة المكرمة
# 3                               ثانوية المشكاة الأهلية           الدمام
# 4                                   ثانوية نجد الأهلية           الرياض
# 5                         ثانوية منارات الرياض الأهلية           الرياض
# 6                               ثانوية الانصار الأهلية           الدمام
# 7     ثانوية الحصان النموذجية الاهلية بالدمام - مقررات           الدمام
# 8                      ثانوية الظهران الاهلية - مقررات            الخبر
# 3    AlSharquia    Domestic  تعليم عام بنين   86.05
# 4        Riyadh    Domestic  تعليم عام بنين   85.57
# 5        Riyadh    Domestic          مقررات    85.4
# 6    AlSharquia    Domestic  تعليم عام بنين   84.93
# 7    AlSharquia    Domestic          مقررات   83.88
# 8    AlSharquia    Domestic          مقررات   83.56
# 9        Riyadh    Domestic  تعليم عام بنين   82.91
# 10       Riyadh    Domestic          مقررات   82.81
# 11       Riyadh    Domestic          مقررات   82.61
# 12       Madina    Domestic          مقررات   81.69
# 13       Riyadh    Domestic  تعليم عام بنين   81.43
# 14       Madina    Domestic          مقررات   81.32
# 15   AlSharquia    Domestic          مقررات   80.98
# 16        Tabuk    Domestic          مقررات    80.3
# 17       Makkah    Domestic          مقررات   79.94
# 18   AlSharquia    Domestic          مقررات    79.7
# 19       Makkah    Domestic  تعليم عام بنين   79.53
# 20       Riyadh    Domestic  تعليم عام بنين   79.14
# 21       Riyadh    Domestic  تعليم عام بنين   78.92
# 22       Makkah    Domestic          مقررات   78.67
# 23       Makkah    Domestic  تعليم عام بنين   78.51
# 24       Riyadh    Domestic          مقررات   78.23
# 25       Riyadh    Domestic          مقررات   78.22
# 26       Riyadh    Domestic          مقررات   77.56
# 27   AlSharquia    Domestic  تعليم عام بنين   77.52
# 28   AlSharquia    Domestic          مقررات   77.39
# 29       Riyadh    Domestic  تعليم عام بنين   77.17
# ..          ...         ...             ...     ...
# 371      Makkah    Domestic  تعليم عام بنين   52.72
# 372        Gouf    Domestic  تعليم عام بنين   52.61
# 373  AlSharquia    Domestic  تعليم عام بنين    52.6
# 374      Riyadh    Domestic  تعليم عام بنين   52.58
# 375  AlSharquia    Domestic  تعليم عام بنين   52.56
# 376  AlSharquia    Domestic  تعليم عام بنين   52.51
# 377      Qassim    Domestic  تعليم عام بنين   52.35
# 378      Najran    Domestic  تعليم عام بنين   52.34
# 379      Riyadh    Domestic  تعليم عام بنين    52.3
# 380      Riyadh    Domestic  تعليم عام بنين   52.28
# 381  AlSharquia    Domestic  تعليم عام بنين   52.23
# 382       Jazan    Domestic  تعليم عام بنين   52.22
# 383      Riyadh    Domestic  تعليم عام بنين   52.17
# 384      Qassim    Domestic  تعليم عام بنين   52.12
# 385  AlSharquia    Domestic  تعليم عام بنين   52.01
# 386      Riyadh    Domestic  تعليم عام بنين   51.94
# 387      Qassim    Domestic  تعليم عام بنين   51.93
# 388  AlSharquia    Domestic  تعليم عام بنين    51.9
# 389      Qassim    Domestic  تعليم عام بنين    51.8
# 390        Gouf    Domestic  تعليم عام بنين    51.5
# 391       Jazan    Domestic  تعليم عام بنين   51.41
# 392      Riyadh    Domestic  تعليم عام بنين   51.38
# 393      Riyadh    Domestic  تعليم عام بنين   50.76
# 394      Riyadh    Domestic  تعليم عام بنين   50.03
# 395      Riyadh    Domestic  تعليم عام بنين   49.83
# 396      Riyadh    Domestic  تعليم عام بنين   49.45
# 397        Gouf    Domestic  تعليم عام بنين   47.49
# 398        Gouf    Domestic  تعليم عام بنين   47.07
# 399      Riyadh    Domestic  تعليم عام بنين   46.34
# 400        Gouf    Domestic  تعليم عام بنين   44.78
#
# [401 rows x 8 columns]

# %%
data_absp.to_csv('ach_boys_sci_priv.csv', index=False)
