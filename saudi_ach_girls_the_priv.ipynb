# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import re
import pandas as pd
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException
from selenium.common.exceptions import NoSuchElementException
import time

# %%
url= 'https://www.qiyas.sa/en/Statistics-Data/Schools/Pages/DetResults.aspx'

#Create a new Safari browser object
driver = webdriver.Safari()
driver.implicitly_wait(100)

#Go to the website
driver.get(url)

##Extract data for Achievement, Girls, Theoretical, Private##
    
#Click on 'Achievement'
driver.find_element_by_xpath('/html/body/form/div[3]/div/div/section/div[2]/div/div[1]/article/div[2]/div[1]/div/div/div/div[1]/div/span/div[1]/div/table/tbody/tr[1]/td/div/div[2]/div/label').click()

#Click on 'Girls'
driver.find_element_by_xpath('/html/body/form/div[3]/div/div/section/div[2]/div/div[1]/article/div[2]/div[1]/div/div/div/div[1]/div/span/div[1]/div/table/tbody/tr[2]/td/div/div[2]/div/label').click() 

#Click on 'Theoretical'
driver.find_element_by_xpath('/html/body/form/div[3]/div/div/section/div[2]/div/div[1]/article/div[2]/div[1]/div/div/div/div[1]/div/span/div[1]/div/table/tbody/tr[3]/td/div/div[2]/div/label').click() 

#Click on 'Private'
driver.find_element_by_xpath('/html/body/form/div[3]/div/div/section/div[2]/div/div[1]/article/div[2]/div[1]/div/div/div/div[1]/div/span/div[1]/div/table/tbody/tr[4]/td/div/div[2]/div').click() 

#Click on 'View the order of all schools'
driver.find_element_by_xpath('/html/body/form/div[3]/div/div/section/div[2]/div/div[1]/article/div[2]/div[1]/div/div/div/div[1]/div/span/div[1]/div/table/tbody/tr[5]/td/span[1]/label').click() 

#Click on 'Submit'
driver.find_element_by_xpath('/html/body/form/div[3]/div/div/section/div[2]/div/div[1]/article/div[2]/div[1]/div/div/div/div[1]/div/span/div[2]/div').click()

# %%
#Retrieving table from first page 
time.sleep(5)
soup_cbsp= BeautifulSoup(driver.page_source, 'html.parser')

#Parse and extract data 
table= soup_cbsp.find_all(class_='table-responsive')[1]

rows=table.find_all('tr')

COLUMNS= ['General Rank', 'Ministerial Number', 'School Name', 
          'City', 'Region', 'School Type', 'Category', 'Average']

sub_df=[]
for row in rows:
    cells= row.select('td')
    cells=cells[0:8]
    sub_df.append([cell.text.strip() for cell in cells])

data_agtp = pd.DataFrame(sub_df, columns=COLUMNS).drop([0,1], axis=0).reset_index(drop=True)
data_agtp
# Out:
#   General Rank Ministerial Number  \
# 0           12              96662
# 1           46              35179
# 2           50              42262
# 3           60              97424
# 4           70              35066
# 5           73              55693
# 6           79              28252
# 7           87              51279
# 8           91             195029
# 9           99             966465
#
#                                     School Name             City      Region  \
# 0  ثانوية دور الذكرالأهلية لتحفيظ القرآن الكريم           الرياض      Riyadh
# 1             ثانوية دارالقلم النموذجية الأهلية              جدة      Makkah
# 2  مدارس طيبة الطيبة الأهلية - المرحلة الثانوية  المدينة المنورة      Madina
# 3    ثانوية الأرقم الأهلية لتحفيظ القرآن الكريم           الرياض      Riyadh
# 4                 ثانوية الذكر بجدة نظام مقررات              جدة      Makkah
# 5               ثانوية مدارس دار البيان الأهلية            الخبر  AlSharquia
# 6        ثانوية دار البشرى الأهلية بمكة المكرمة      مكة المكرمة      Makkah
# 7                       ثانوية الرشاد النموذجيه             الرس      Qassim
# 8             ثانوية الفرسان الأهلية - المقررات           الرياض      Riyadh
# 9   ثانوية الرواد الأهلية ( الازدهار ) - مقررات           الرياض      Riyadh
#
#   School Type        Category Average
# 0    Domestic      تحفيظ بنات   78.63
# 1    Domestic  تعليم عام بنات   75.44
# 2    Domestic  تعليم عام بنات   75.12
# 3    Domestic      تحفيظ بنات   74.55
# 4    Domestic          مقررات    73.6
# 5    Domestic  تعليم عام بنات   73.32
# 6    Domestic  تعليم عام بنات      73
# 7    Domestic  تعليم عام بنات   72.33
# 8    Domestic          مقررات   72.29
# 9    Domestic          مقررات   72.12

# %%
while True: 
    try: 
        next_page_btn= driver.find_elements(By.CLASS_NAME, "Next")
        if not next_page_btn:
            print("No next button")
            break
        next_btn= next_page_btn[0]
        if next_btn.get_attribute("class")== "aspNetDisabled Next":
            print("No more pages left")
            break
        else: 
            WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.CLASS_NAME, "Next"))).click()
        
            time.sleep(10)
        
            soup_pgs= BeautifulSoup(driver.page_source, 'html.parser')
        
            #Parse and extract data 
        
            table_pgs= soup_pgs.find_all(class_='table-responsive')[1]
        
            rows_pgs=table_pgs.find_all('tr')
        
            COLUMNS_pgs= ['General Rank', 'Ministerial Number', 'School Name', 
                  'City', 'Region', 'School Type', 'Category', 'Average']
        
            sub_df_pgs=[]
            for row_pgs in rows_pgs:
                cells_pgs= row_pgs.select('td')
                cells_pgs=cells_pgs[0:8]
                sub_df_pgs.append([cell_pgs.text.strip() for cell_pgs in cells_pgs])
        
            data_pgs = pd.DataFrame(sub_df_pgs, columns=COLUMNS_pgs).drop([0,1], axis=0).reset_index(drop=True)
            data_agtp=data_agtp.append(data_pgs, ignore_index=True)
        
    except TimeoutException:
        print("Exception has been thrown. No more pages left")
        break
driver.quit()
# Out:
# No more pages left

# %%
data_agtp
# Out:
#     General Rank Ministerial Number  \
# 0             12              96662
# 1             46              35179
# 2             50              42262
# 3             60              97424
# 4             70              35066
# 5             73              55693
# 6             79              28252
# 7             87              51279
# 8             91             195029
# 9             99             966465
# 10           104              35080
# 11           110              42356
# 12           127              59099
# 13           131              59008
# 14           215              97128
# 15           221              96627
# 16           228              96634
# 17           245              97423
# 18           250              42250
# 19           283              35078
# 20           284              35063
# 21           293             351805
# 22           320              96969
# 23           328              42347
# 24           330             590215
# 25           349             966645
# 26           431              42355
# 27           483              42271
# 28           496              96940
# 29           509              59187
# ..           ...                ...
# 117         1343              96666
# 118         1344              51270
# 119         1346              51284
# 120         1354             966255
# 121         1356              49042
# 122         1360              63698
# 123         1366              31547
# 124         1370              56235
# 125         1371              60844
# 126         1377              31235
# 127         1387              96645
# 128         1397              35216
# 129         1400              60762
# 130         1427              49157
# 131         1445              60845
# 132         1453              35143
# 133         1469              31429
# 134         1490              96980
# 135         1492              97070
# 136         1504              28357
# 137         1529              60831
# 138         1556              35145
# 139         1558              60817
# 140         1574              60738
# 141         1578              48918
# 142         1579              96653
# 143         1585              48963
# 144         1608              75068
# 145         1617              60814
# 146         1625             186879
#
#                                            School Name             City  \
# 0         ثانوية دور الذكرالأهلية لتحفيظ القرآن الكريم           الرياض
# 1                    ثانوية دارالقلم النموذجية الأهلية              جدة
# 2         مدارس طيبة الطيبة الأهلية - المرحلة الثانوية  المدينة المنورة
# 3           ثانوية الأرقم الأهلية لتحفيظ القرآن الكريم           الرياض
# 4                        ثانوية الذكر بجدة نظام مقررات              جدة
# 5                      ثانوية مدارس دار البيان الأهلية            الخبر
# 6               ثانوية دار البشرى الأهلية بمكة المكرمة      مكة المكرمة
# 7                              ثانوية الرشاد النموذجيه             الرس
# 8                    ثانوية الفرسان الأهلية - المقررات           الرياض
# 9          ثانوية الرواد الأهلية ( الازدهار ) - مقررات           الرياض
# 10                                     ثانوية المستقبل              جدة
# 11         مدارس درر المدينة الأهلية- المرحلة الثانوية  المدينة المنورة
# 12                             ثانوية النخبة النموذجية          الأحساء
# 13                           ثانوية دور العلوم الأهلية          الأحساء
# 14                    ثانوية التعاون النموذجية الأهلية           الرياض
# 15                      ثانوية الدوحة السعودية الأهلية           الرياض
# 16                                ثانوية السمو الأهلية           الرياض
# 17                               ثانوية الأرقم الأهلية           الرياض
# 18         مدارس دار الأمان الأهلية - المرحلة الثانوية  المدينة المنورة
# 19                                       ثانوية العقيق              جدة
# 20                           ثانوية روضة جدة النموذجية              جدة
# 21                     ثانوية الاندلس بجدة نظام مقررات              جدة
# 22                              ثانوية الإحسان الأهلية           الرياض
# 23    مدارس العقيق الأهلية - المرحلة الثانوية (مقررات)  المدينة المنورة
# 24   مدارس أكاديمية الكفاح الأهلية للتعليم - الثانو...          الأحساء
# 25                     ثانوية التربية الأهلية - مقررات           الرياض
# 26      مدارس أنوار الفيحاء الأهلية - المرحلة الثانوية  المدينة المنورة
# 27       مدارس المعتز بالله الأهلية - المرحلة الثانوية  المدينة المنورة
# 28                                ثانوية الوسط الأهلية           الرياض
# 29                                ثانوية رؤية المستقبل          الأحساء
# ..                                                 ...              ...
# 117                             ثانوية الزهراء الأهلية           الرياض
# 118                                      ثانوية الغصون             الرس
# 119                               ثانوية الوعد الاهلية             الرس
# 120                 ثانوية دار السلام الأهلية - مقررات           الرياض
# 121                   ثانوية فجر القصيم الأهلية ببريدة            بريدة
# 122                         ثانوية  مدارس أبها الأهلية             أبها
# 123         ثانوية صروح العلم والتربية الأهلية بالطائف           الطائف
# 124            ثانوية مدارس درر الجزيرة الاهلية للبنات            الخبر
# 125                         ثانوية نور التوحيد الأهلية       حفر الباطن
# 126               ثانوية أنجال المملكة الأهلية بالطائف           الطائف
# 127                         ثانوية شبه الجزيرة الأهلية           الرياض
# 128                         ثانوية جيل الحضارة الاهلية              جدة
# 129                      ثانوية  تربية الأجيال الأهلية       حفر الباطن
# 130   ثانوية فجر القصيم الاهلية لتعليم الكبيرات ببريدة            بريدة
# 131                         ثانوية منار السبيل الأهلية       حفر الباطن
# 132                               ثانوية الطفل المثالي              جدة
# 133                  ثانوية واحة الفكر الأهلية بالطائف           الطائف
# 134                             ثانوية الديوان الأهلية           الرياض
# 135                        ثانوية أضواء الرياض الأهلية           الرياض
# 136                 ثانوية البتول الأهلية بمكة المكرمة      مكة المكرمة
# 137                         ثانوية رواد النجاح الأهلية       حفر الباطن
# 138                                      ثانوية الشعلة              جدة
# 139                  ثانوية الأكاديمية العصرية الأهلية       حفر الباطن
# 140                              ثانوية الواحة الأهلية       حفر الباطن
# 141                 ثانوية أنجال القصيم الأهلية ببريدة            بريدة
# 142                               ثانوية الشفا الأهلية           الرياض
# 143                       ثانوية البيان الأهلية ببريدة            بريدة
# 144                    ثانوية التربية  الإسلامية بحائل             حائل
# 145                               ثانوية المجد الأهلية       حفر الباطن
# 146                  ثانوية بيت القيم الاهلية بالقريات          القريات
#
#          Region School Type        Category Average
# 0        Riyadh    Domestic      تحفيظ بنات   78.63
# 1        Makkah    Domestic  تعليم عام بنات   75.44
